# %% [markdown]
# First, let's try to see what the data look like.

# %%
# import the neccessary package

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
#read in the data

#data1 = pd.read_csv("../visualization/data/ExcelFormattedGISTEMPDataCSV.csv")
data1 = pd.read_csv("./data/ExcelFormattedGISTEMPDataCSV.csv")
print('The first data:')
display(data1.head(n = 5))
data2 = pd.read_csv('./data/ExcelFormattedGISTEMPData2CSV.csv')
print("The second data:")
display(data2.head(n = 5))
# Out:
# The first data:
#    Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  J-D  D-N  \
# 0  1880  -29  -19  -17  -27  -13  -28  -22   -6  -16  -15  -18  -20  -19  ***
# 1  1881   -8  -13    2   -2   -3  -27   -5   -1   -8  -18  -25  -14  -10  -11
# 2  1882   10   10    2  -19  -17  -24   -9    5    0  -21  -20  -24   -9   -8
# 3  1883  -32  -41  -17  -23  -24  -11   -7  -12  -18  -11  -19  -17  -19  -20
# 4  1884  -17  -11  -33  -35  -31  -37  -33  -25  -22  -22  -30  -28  -27  -26
#
#     DJF  MAM  JJA  SON
# 0  ****  -19  -19  -16
# 1   -13   -1  -11  -17
# 2     2  -11   -9  -14
# 3   -32  -22  -10  -16
# 4   -15  -33  -32  -25
# The second data:
#    Year  Glob  NHem  SHem  24N-90N  24S-24N  90S-24S  64N-90N  44N-64N  \
# 0  1880   -19   -33    -5      -38      -16       -5      -89      -54
# 1  1881   -10   -18    -2      -27       -2       -5      -54      -40
# 2  1882    -9   -17    -1      -21      -10        4     -125      -20
# ...

# %% [markdown]
# # Visualization
# Let's visualize the first data.

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
plt.style.use('seaborn-dark')

# %%
data1.plot(x = 'Year')

# %% [markdown]
# The x axis is 'Year'. The y axis is temperature. Every line in the graph stands for a month in the year or an average temperature through 2 or 3 months.
# The graph shows that the average temperature keeps on rising as time goes by.
